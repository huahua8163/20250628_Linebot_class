# %%
import requests

def chat_with_ollama(prompt: str):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "gemma3:1b",
        "prompt": prompt,
        "stream": False,
        "options": { #參考說明1
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 50,
        },
        "max_tokens": 100,
        "format": "json",
    }

    response = requests.post(url, json=payload)
    result = response.json()
    print("💬 AI 回應：")
    # Print the whole result for debugging
    print(result)
    # Try to print the 'response' key if it exists, otherwise print possible keys
    if "response" in result:
        print(result["response"])
    elif "message" in result:
        print(result["message"])
    elif "content" in result:
        print(result["content"])
    else:
        print("No expected key found in response. Available keys:", result.keys())

#範例輸入
chat_with_ollama("請問你是誰？")  # Example input
# Out:
# 💬 AI 回應：
# {'model': 'gemma3:1b', 'created_at': '2025-08-09T05:15:41.949178429Z', 'response': '{ \n    "我是": "Google大語言模型", "由":"Google" \n    }', 'done': True, 'done_reason': 'stop', 'context': [105, 2364, 107, 130557, 95841, 240560, 237536, 106, 107, 105, 4368, 107, 236782, 236743, 107, 140, 236775, 44889, 1083, 623, 19540, 237110, 146569, 26609, 827, 623, 237852, 12375, 19540, 236775, 236743, 107, 140, 236783], 'total_duration': 15828501993, 'load_duration': 11674562582, 'prompt_eval_count': 13, 'prompt_eval_duration': 532727607, 'eval_count': 25, 'eval_duration': 3309010493}
# {
#     "我是": "Google大語言模型", "由":"Google"
#     }
