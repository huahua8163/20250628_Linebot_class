# %%
from google import genai
import os
from dotenv import load_dotenv

# 載入環境變數
load_dotenv(override=True)

# 使用環境變數中的 API 密鑰
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

# 使用 stream 版本
response = client.models.generate_content_stream(
    model="gemini-1.5-flash",  # 改成正確的模型名稱
    contents=["AI是如何工作的(請使用繁體中文回答)?"],
)

for chunk in response:
    print(chunk.text, end="")
# Out:
# AI，也就是人工智慧，並非單一技術，而是一系列技術的集合，目標是讓電腦模擬人類的智慧。  其工作原理可以大致歸納為以下幾個方面：
#
# **1. 資料收集與預處理:**  AI系統需要大量的資料來學習。這些資料可以是文字、圖片、聲音、影片等等。在訓練模型之前，這些資料需要經過清洗、轉換和標注等預處理步驟，以確保資料的質量和一致性。例如，去除噪聲、處理缺失值、將文字轉換為數字向量等。
#
# **2. 特徵工程 (Feature Engineering):**  這一步驟是將原始資料轉換成算法可以理解的數學表示。  簡單來說，就是從資料中提取出對預測結果有用的特徵。  例如，在圖片辨識中，特徵可能是邊緣、角點、顏色等等。  好的特徵工程對於模型的性能至關重要。  近年來，深度學習的興起減少了對人工特徵工程的依賴，因為深度學習模型可以自動學習特徵。
#
# **3. 模型訓練:**  這是AI的核心步驟。  利用預處理後的資料，訓練一個模型來學習資料中的規律和模式。  常用的模型包括：
#
# * **監督學習 (Supervised Learning):**  模型從已標註的資料中學習，例如，給模型大量的圖片和對應的標籤（例如，「貓」、「狗」），讓模型學習如何區分貓和狗。
# * **非監督學習 (Unsupervised Learning):**  模型從未標註的資料中學習，例如，讓模型從大量的客戶資料中自動發現客戶群體。
# * **強化學習 (Reinforcement Learning):**  模型通過與環境互動來學習，例如，訓練一個機器人玩遊戲，通過獎勵和懲罰來學習最佳策略。
#
# 訓練過程通常涉及到調整模型的參數，以最小化預測誤差。  這個過程需要大量的計算資源。
#
# **4. 模型評估:**  訓練完成後，需要評估模型的性能，例如，使用精度、召回率、F1值等指標來衡量模型的準確性。  如果性能不理想，則需要調整模型的參數或選擇不同的模型。
#
# **5. 模型部署與應用:**  經過評估的模型可以部署到實際應用中，例如，用於圖片辨識、語音識別、自然語言處理等等。
#
# **不同類型的AI:**  上述步驟是AI系統通用的工作原理，但不同的AI技術有其獨特的特性：
#
# * **機器學習 (Machine Learning):**  讓電腦從資料中學習，而不需要明確編寫程式來解決特定問題。
# * **深度學習 (Deep Learning):**  一種基於人工神經網路的機器學習方法，能夠處理更複雜的資料和任務。
# * **自然語言處理 (Natural Language Processing, NLP):**  讓電腦理解和處理人類語言。
# * **電腦視覺 (Computer Vision):**  讓電腦「看」懂圖片和影片。
#
#
# 總之，AI的工作原理是一個複雜的過程，涉及到資料科學、數學、統計學、電腦科學等多個領域的知識。  隨著技術的發展，AI系統也越來越複雜和強大。

# %%
for item in [5, 9, 10]:
    print(item)
# Out:
# 5
# 9
# 10
